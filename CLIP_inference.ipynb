# %%
## SPECIFY THESE ##
DATASET_FOLDER = '../dataset/20240320_22_33_11_fps1_clip_1_0/' # folder of images
# use environment vclap

# %%
import os
# Path Configs
PATH_DEPTH  = DATASET_FOLDER + 'depth/'
PATH_COLOR = DATASET_FOLDER + 'color'
PATH_ACT = DATASET_FOLDER + 'activity_recognition'
os.makedirs(PATH_ACT, exist_ok=True)

# %%
import numpy as np
import torch
from pkg_resources import packaging

print("Torch version:", torch.__version__)

import clip

clip.available_models()
# Out:
# Torch version: 2.1.2+cu118
# ['RN50',
#  'RN101',
#  'RN50x4',
#  'RN50x16',
#  'RN50x64',
#  'ViT-B/32',
#  'ViT-B/16',
#  'ViT-L/14',
#  'ViT-L/14@336px']

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

#model, preprocess = clip.load("ViT-B/32", device)
model, preprocess = clip.load("RN101", device)
model.eval()
input_resolution = model.visual.input_resolution
context_length = model.context_length
vocab_size = model.vocab_size

print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in model.parameters()]):,}")
print("Input resolution:", input_resolution)
print("Context length:", context_length)
print("Vocab size:", vocab_size)
# Out:
# Model parameters: 119,688,033
# Input resolution: 224
# Context length: 77
# Vocab size: 49408

# %%
# Class label csv path
labels_csv_path = 'kinetics_400_labels.csv'

# Read Class labels
import csv

label2id = {}
id2label = {}
with open(labels_csv_path, mode='r') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)

    for row in csv_reader:
        class_id, class_name = row
        label2id[class_name] = class_id
        id2label[class_id] = class_name

class_labels = list(label2id.keys())

print(f"{len(class_labels)} Unique classes: {class_labels}.")
# Out:
# 400 Unique classes: ['abseiling', 'air drumming', 'answering questions', 'applauding', 'applying cream', 'archery', 'arm wrestling', 'arranging flowers', 'assembling computer', 'auctioning', 'baby waking up', 'baking cookies', 'balloon blowing', 'bandaging', 'barbequing', 'bartending', 'beatboxing', 'bee keeping', 'belly dancing', 'bench pressing', 'bending back', 'bending metal', 'biking through snow', 'blasting sand', 'blowing glass', 'blowing leaves', 'blowing nose', 'blowing out candles', 'bobsledding', 'bookbinding', 'bouncing on trampoline', 'bowling', 'braiding hair', 'breading or breadcrumbing', 'breakdancing', 'brush painting', 'brushing hair', 'brushing teeth', 'building cabinet', 'building shed', 'bungee jumping', 'busking', 'canoeing or kayaking', 'capoeira', 'carrying baby', 'cartwheeling', 'carving pumpkin', 'catching fish', 'catching or throwing baseball', 'catching or throwing frisbee', 'catching or throwing softball', 'celebrating', 'changing oil', 'changing wheel', 'checking tires', 'cheerleading', 'chopping wood', 'clapping', 'clay pottery making', 'clean and jerk', 'cleaning floor', 'cleaning gutters', 'cleaning pool', 'cleaning shoes', 'cleaning toilet', 'cleaning windows', 'climbing a rope', 'climbing ladder', 'climbing tree', 'contact juggling', 'cooking chicken', 'cooking egg', 'cooking on campfire', 'cooking sausages', 'counting money', 'country line dancing', 'cracking neck', 'crawling baby', 'crossing river', 'crying', 'curling hair', 'cutting nails', 'cutting pineapple', 'cutting watermelon', 'dancing ballet', 'dancing charleston', 'dancing gangnam style', 'dancing macarena', 'deadlifting', 'decorating the christmas tree', 'digging', 'dining', 'disc golfing', 'diving cliff', 'dodgeball', 'doing aerobics', 'doing laundry', 'doing nails', 'drawing', 'dribbling basketball', 'drinking', 'drinking beer', 'drinking shots', 'driving car', 'driving tractor', 'drop kicking', 'drumming fingers', 'dunking basketball', 'dying hair', 'eating burger', 'eating cake', 'eating carrots', 'eating chips', 'eating doughnuts', 'eating hotdog', 'eating ice cream', 'eating spaghetti', 'eating watermelon', 'egg hunting', 'exercising arm', 'exercising with an exercise ball', 'extinguishing fire', 'faceplanting', 'feeding birds', 'feeding fish', 'feeding goats', 'filling eyebrows', 'finger snapping', 'fixing hair', 'flipping pancake', 'flying kite', 'folding clothes', 'folding napkins', 'folding paper', 'front raises', 'frying vegetables', 'garbage collecting', 'gargling', 'getting a haircut', 'getting a tattoo', 'giving or receiving award', 'golf chipping', 'golf driving', 'golf putting', 'grinding meat', 'grooming dog', 'grooming horse', 'gymnastics tumbling', 'hammer throw', 'headbanging', 'headbutting', 'high jump', 'high kick', 'hitting baseball', 'hockey stop', 'holding snake', 'hopscotch', 'hoverboarding', 'hugging', 'hula hooping', 'hurdling', 'hurling (sport)', 'ice climbing', 'ice fishing', 'ice skating', 'ironing', 'javelin throw', 'jetskiing', 'jogging', 'juggling balls', 'juggling fire', 'juggling soccer ball', 'jumping into pool', 'jumpstyle dancing', 'kicking field goal', 'kicking soccer ball', 'kissing', 'kitesurfing', 'knitting', 'krumping', 'laughing', 'laying bricks', 'long jump', 'lunge', 'making a cake', 'making a sandwich', 'making bed', 'making jewelry', 'making pizza', 'making snowman', 'making sushi', 'making tea', 'marching', 'massaging back', 'massaging feet', 'massaging legs', "massaging person's head", 'milking cow', 'mopping floor', 'motorcycling', 'moving furniture', 'mowing lawn', 'news anchoring', 'opening bottle', 'opening present', 'paragliding', 'parasailing', 'parkour', 'passing American football (in game)', 'passing American football (not in game)', 'peeling apples', 'peeling potatoes', 'petting animal (not cat)', 'petting cat', 'picking fruit', 'planting trees', 'plastering', 'playing accordion', 'playing badminton', 'playing bagpipes', 'playing basketball', 'playing bass guitar', 'playi ...

# %%
from tqdm.notebook import tqdm
import cv2
import os
from PIL import Image
import csv
device = "cuda" if torch.cuda.is_available() else "cpu"

for filename in tqdm(os.listdir(PATH_COLOR)):

    image_input = preprocess(Image.open(os.path.join(PATH_COLOR, filename))).unsqueeze(0).to(device)
    text_inputs = torch.cat([clip.tokenize(f"a photo of a {c}")for c in class_labels]).to(device)

    with torch.no_grad():
        image_features = model.encode_image(image_input)
        text_features = model.encode_text(text_inputs)
    
        logits_per_image, logits_per_text = model(image_input, text_inputs)
        similarity = logits_per_image.softmax(dim=-1)
        values, indices = similarity[0].topk(5)
        pred_index = indices[0]

    # Print the results
    print("Top predictions:\n")
    for value, index in zip(values, indices):
        print(f"{class_labels[index]:>16s}: {100 * value.item():.2f}%")

    # save the results to csv
    csv_path = os.path.join(PATH_ACT, filename)[:-3] + 'csv'
    with open(csv_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        # Write the header row
        writer.writerow(['Class Label', 'Probability'])
        # Write the class labels and probabilities to the CSV file
        for value, index in zip(values, indices):
            writer.writerow([class_labels[index], f"{100 * value.item():.2f}%"])
# Out:
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Top predictions:
#
#          writing: 15.22%
# using remote controller (not gaming): 14.29%
# arranging flowers: 5.10%
#    setting table: 4.50%
#  opening present: 4.50%
# Top predictions:
#
#          writing: 12.70%
# using remote controller (not gaming): 9.29%
#    setting table: 7.95%
# arranging flowers: 6.59%
#           dining: 5.81%
# Top predictions:
#
#          writing: 15.36%
# using remote controller (not gaming): 11.23%
# arranging flowers: 8.22%
#    setting table: 4.83%
#   using computer: 3.88%
# Top predictions:
#
#          writing: 15.05%
# using remote controller (not gaming): 11.36%
# arranging flowers: 7.57%
#    setting table: 5.37%
#   using computer: 4.59%
# Top predictions:
#
#          writing: 13.83%
# using remote controller (not gaming): 12.20%
# arranging flowers: 7.64%
#   using computer: 5.25%
#    playing poker: 4.63%
# Top predictions:
#
#          writing: 15.36%
# using remote controller (not gaming): 11.59%
# arranging flowers: 7.48%
#    setting table: 5.65%
#   using computer: 4.83%
# Top predictions:
#
#          writing: 14.25%
# using remote controller (not gaming): 11.09%
# arranging flowers: 6.52%
#    playing poker: 5.58%
#    setting table: 5.40%
# Top predictions:
#
#          writing: 16.52%
# using remote controller (not gaming): 11.35%
# arranging flowers: 5.89%
#    setting table: 5.71%
#   using computer: 4.88%
# Top predictions:
#
#          writing: 17.75%
# using remote controller (not gaming): 12.99%
# arranging flowers: 7.63%
#   using computer: 7.40%
#    playing poker: 4.09%
# Top predictions:
#
#          writing: 15.53%
# using remote controller (not gaming): 13.28%
# arranging flowers: 5.54%
#   using computer: 5.37%
#    setting table: 4.89%
# Top predictions:
#
#          writing: 18.15%
# using remote controller (not gaming): 12.09%
# arranging flowers: 7.81%
#    setting table: 5.04%
#   using computer: 4.73%
# Top predictions:
#
#          writing: 16.63%
# using remote controller (not gaming): 12.16%
# arranging flowers: 6.12%
#   using computer: 5.07%
#    setting table: 4.91%
# Top predictions:
#
#          writing: 15.65%
# using remote controller (not gaming): 11.45%
# arranging flowers: 8.12%
#    setting table: 6.32%
#   using computer: 4.92%
# Top predictions:
#
#          writing: 16.44%
# using remote controller (not gaming): 9.97%
# arranging flowers: 6.65%
#    setting table: 6.24%
#    playing poker: 4.29%
# Top predictions:
#
#          writing: 12.49%
# using remote controller (not gaming): 11.74%
# arranging flowers: 6.48%
#    setting table: 5.90%
#    playing poker: 4.18%
# Top predictions:
#
#          writing: 16.56%
# using remote controller (not gaming): 8.33%
# arranging flowers: 7.13%
#    setting table: 6.49%
#   using computer: 4.46%
# Top predictions:
#
#          writing: 13.40%
# using remote controller (not gaming): 10.77%
# arranging flowers: 9.21%
#    setting table: 8.13%
#           dining: 4.78%
# Top predictions:
#
#          writing: 18.29%
# using remote controller (not gaming): 10.75%
# arranging flowers: 7.39%
#    setting table: 5.75%
#   using computer: 4.62%
# Top predictions:
#
# using remote controller (not gaming): 14.78%
#          writing: 12.65%
# arranging flowers: 5.44%
#  opening present: 3.86%
#    setting table: 3.62%
# Top predictions:
#
#          writing: 15.19%
# using remote controller (not gaming): 9.21%
#           dining: 6.74%
#    setting table: 6.53%
# arranging flowers: 4.93%
# Top predictions:
#
#          writing: 17.15%
# using remote controller (not gaming): 9.77%
# arranging flowers: 5.57%
#      doing nails: 4.92%
#           dining: 4.21%
# Top predictions:
#
#          writing: 13.68%
# using remote controller (not gaming): 11.35%
# arranging flowers: 5.70%
#           dining: 4.17%
#    setting table: 4.04%
# Top predictions:
#
#          writing: 17.69%
# using remote controller (not gaming): 10.39%
# arranging flowers: 4.91%
#    playing poker: 4.76%
#   eating carrots: 4.07%
# Top predictions:
#
#          writing: 15.50%
# using remote controller (not gaming): 10.33%
#      doing nails: 6.88%
# arranging flowers: 4.88%
#   using computer: 4.73%
# Top predictions:
#
#          writing: 13.28%
# using remote controller (not gaming): 11.72%
#           dining: 5.04%
#   eating carrots: 4.45%
# arranging flowers: 3.93%
# Top predictions:
#
#          writing: 12.76%
# using remote controller (not gaming): 9.94%
#   eating carrots: 6.83%
#           dining: 6.02%
# arranging flowers: 3.65%
# Top predictions:
#
#          writing: 13.33%
# using remote controller (not gaming): 10.38%
#   eating carrots: 5.73%
#      doing nails: 4.06%
#   using computer: 3.70%
# Top predictions:
#
#          writing: 14.04%
# using remote controller (not gaming): 9.95%
#   eating carrots: 5.16%
#    playing poker: 4.56%
#      doing nails: 3.34%
# Top predictions:
#
#          writing: 13.72%
# using remote controller (not gaming): 8.59%
#   eating carrots: 5.55%
#           dining: 4.46%
# arranging flowers: 4.06%
# Top predictions:
#
#          writing: 17.14%
# using remote controller (not gaming): 9.76%
#   eating carrots: 5.39%
# arranging flowers: 3.94%
#           dining: 3.59%
# Top predictions:
#
#          writing: 13.92%
# using remote controller (not gaming): 9.27%
#      doing nails: 6.17%
#   eating carrots: 5.12%
# arranging flowers: 4.66%
# Top predictions:
#
#          writing: 10.64%
# using remote controller (not gaming): 8.54%
#   eating carrots: 5.35%
#      doing nails: 4.57%
#           dining: 4.30%
# Top predictions:
#
#          writing: 14.84%
# using remote controller (not gaming): 12.70%
#   eating carrots: 5.29%
#           dining: 3.52%
# arranging flowers: 3.31%
# Top predictions:
#
#          writing: 13.46%
# using remote controller (not gaming): 6.98%
#   eating carrots: 6.16%
#           dining: 5.44%
#      doing nails: 3.86%
# Top predictions:
#
#          writing: 15.26%
# using remote controller (not gaming): 6.99%
#           dining: 5.44%
#   eating carrots: 5.11%
# arranging flowers: 3.51%
# Top predictions:
#
#          writing: 12.08%
# using remote controller (not gaming): 11.35%
#   eating carrots: 6.07%
#           dining: 4.44%
#      doing nails: 3.46%
# Top predictions:
#
#          writing: 14.83%
# using remote controller (not gaming): 7.94%
#      doing nails: 5.46%
#   eating carrots: 5.29%
# arranging flowers: 2.92%
# Top predictions:
#
#          writing: 15.03%
# using remote controller (not gaming): 9.11%
#           dining: 4.73%
# arranging flowers: 4.58%
#   eating carrots: 4.44%
# Top predictions:
#
#          writing: 13.39%
# using remote controller (not gaming): 8.12%
#   eating carrots: 5.94%
#           dining: 4.35%
#      doing nails: 4.09%
# Top predictions:
#
#          writing: 14.95%
# using remote controller (not gaming): 6.85%
#           dining: 5.01%
#   eating carrots: 4.56%
#      doing nails: 3.90%
# Top predictions:
#
#          writing: 12.98%
# using remote controller (not gaming): 7.17%
#   eating carrots: 7.17%
#      doing nails: 5.08%
#           dining: 4.77%
# Top predictions:
#
#          writing: 13.26%
# using remote controller (not gaming): 9.41%
#   eating carrots: 5.36%
#           dining: 4.58%
# arranging flowers: 3.92%
# Top predictions:
#
#          writing: 12.93%
# using remote controller (not gaming): 7.60%
#   eating carrots: 6.70%
#           dining: 5.92%
#      doing nails: 4.61%
# Top predictions:
#
#          writing: 14.27%
# using remote controller (not gaming): 9.51%
#   eating carrots: 5.25%
# arranging flowers: 4.35%
#      doing nails: 3.84%
# Top predictions:
#
#          writing: 12.35%
#   eating carrots: 6.82%
# using remote controller (not gaming): 6.21%
#           dining: 5.84%
#      doing nails: 4.14%
# Top predictions:
#
#          writing: 14.54%
# using remote controller (not gaming): 6.66%
#   eating carrots: 6.26%
#           dining: 5.35%
#      doing nails: 4.04%
# Top predictions:
#
#          writing: 15.47%
# using remote controller (not gaming): 10.96%
# arranging flowers: 6.65%
#    setting table: 4.29%
#           dining: 4.03%
# Top predictions:
#
#          writing: 18.77%
# using remote controller (not gaming): 10.70%
# arranging flowers: 6.70%
#      doing nails: 4.06%
#           dining: 3.16%
# Top predictions:
#
#          writing: 15.72%
# using remote controller (not gaming): 12.24%
# arranging flowers: 7.90%
#      doing nails: 3.62%
#           dining: 3.40%
# Top predictions:
#
#          writing: 16.72%
# using remote controller (not gaming): 10.14%
# arranging flowers: 6.15%
#      doing nails: 3.85%
#           dining: 3.62%
# Top predictions:
#
#          writing: 16.81%
# using remote controller (not gaming): 9.58%
# arranging flowers: 4.97%
#      doing nails: 4.12%
#           dining: 3.31%
# Top predictions:
#
#          writing: 18.12%
# using remote controller (not gaming): 10.99%
# arranging flowers: 5.35%
#   using computer: 4.17%
#      doing nails: 3.46%
# Top predictions:
#
#          writing: 17.70%
# using remote controller (not gaming): 11.79%
# arranging flowers: 6.12%
#      doing nails: 3.71%
#   eating carrots: 3.38%
# Top predictions:
#
#          writing: 19.04%
# using remote controller (not gaming): 9.88%
# arranging flowers: 6.58%
#      doing nails: 4.39%
#  opening present: 2.92%
# Top predictions:
#
#          writing: 16.59%
# using remote controller (not gaming): 12.14%
# arranging flowers: 6.10%
#      doing nails: 3.70%
#   eating carrots: 3.37%
# Top predictions:
#
#          writing: 18.27%
# using remote controller (not gaming): 10.75%
# arranging flowers: 6.52%
#   using computer: 3.18%
#    setting table: 2.80%
# Top predictions:
#
#          writing: 17.05%
# using remote controller (not gaming): 12.88%
# arranging flowers: 6.68%
#    setting table: 3.81%
#           dining: 3.36%
# Top predictions:
#
#          writing: 16.83%
# using remote controller (not gaming): 13.11%
# arranging flowers: 5.82%
#   using computer: 3.64%
#      doing nails: 3.64%
# Top predictions:
#
#          writing: 20.13%
# using remote controller (not gaming): 11.12%
# arranging flowers: 5.95%
#    playing poker: 4.09%
#           dining: 3.96%
# Top predictions:
#
#          writing: 17.04%
# using remote controller (not gaming): 12.46%
# arranging flowers: 5.71%
#      doing nails: 3.69%
#   using computer: 3.57%
# Top predictions:
#
#          writing: 18.46%
# using remote controller (not gaming): 10.19%
# arranging flowers: 5.99%
#    setting table: 4.12%
#  opening present: 3.63%
# Top predictions:
#
#          writing: 20.34%
# using remote controller (not gaming): 9.61%
# arranging flowers: 5.65%
#      doing nails: 3.88%
#           dining: 3.53%
# Top predictions:
#
#          writing: 16.47%
# using remote controller (not gaming): 9.39%
# arranging flowers: 6.65%
#    setting table: 4.87%
#           dining: 4.72%
# Top predictions:
#
#          writing: 18.40%
# using remote controller (not gaming): 9.25%
# arranging flowers: 5.97%
#           dining: 3.98%
#    setting table: 3.74%
# Top predictions:
#
#          writing: 18.31%
# using remote controller (not gaming): 9.80%
# arranging flowers: 6.13%
#    setting table: 4.49%
#           dining: 3.96%
# Top predictions:
#
#          writing: 15.44%
# using remote controller (not gaming): 13.62%
# arranging flowers: 5.86%
#    setting table: 3.55%
#      doing nails: 3.45%
# Top predictions:
#
#          writing: 18.08%
# using remote controller (not gaming): 11.32%
# arranging flowers: 6.25%
#      doing nails: 3.91%
#   eating carrots: 3.24%
# Top predictions:
#
#          writing: 16.67%
# using remote controller (not gaming): 10.11%
# arranging flowers: 5.09%
#    setting table: 3.39%
#           dining: 3.28%
# Top predictions:
#
#          writing: 17.33%
# using remote controller (not gaming): 12.68%
# arranging flowers: 6.79%
#   using computer: 3.21%
#      doing nails: 3.11%
# Top predictions:
#
#          writing: 16.61%
# using remote controller (not gaming): 12.15%
# arranging flowers: 5.92%
#    setting table: 4.47%
#  opening present: 3.59%
# Top predictions:
#
#          writing: 18.60%
# using remote controller (not gaming): 12.01%
# arranging flowers: 6.23%
#   using computer: 3.66%
#           dining: 3.34%
# Top predictions:
#
#          writing: 16.74%
# using remote controller (not gaming): 9.25%
#           dining: 5.27%
# arranging flowers: 4.50%
#    setting table: 3.62%
# Top predictions:
#
#          writing: 17.18%
# using remote controller (not gaming): 11.44%
# arranging flowers: 6.52%
#    setting table: 3.28%
#           dining: 2.80%
# Top predictions:
#
#          writing: 16.80%
# using remote controller (not gaming): 10.19%
# arranging flowers: 5.12%
#   eating carrots: 4.25%
#      doing nails: 3.63%
# Top predictions:
#
#          writing: 15.15%
# using remote controller (not gaming): 12.17%
# arranging flowers: 6.31%
#      doing nails: 3.95%
#   using computer: 3.60%
# Top predictions:
#
#          writing: 16.54%
# using remote controller (not gaming): 8.32%
# arranging flowers: 4.74%
#      doing nails: 3.81%
#           dining: 3.81%
# Top predictions:
#
#          writing: 19.57%
# using remote controller (not gaming): 8.42%
# arranging flowers: 6.98%
#   eating carrots: 3.85%
#    setting table: 3.74%
# Top predictions:
#
#          writing: 18.55%
# using remote controller (not gaming): 9.63%
# arranging flowers: 6.82%
#           dining: 4.14%
#      doing nails: 3.43%
# Top predictions:
#
#          writing: 15.20%
# using remote controller (not gaming): 10.12%
# arranging flowers: 6.96%
#           dining: 4.78%
#    setting table: 4.49%
# Top predictions:
#
#          writing: 19.89%
# using remote controller (not gaming): 11.69%
# arranging flowers: 5.03%
#      doing nails: 3.68%
#   using computer: 3.35%
# Top predictions:
#
#          writing: 15.86%
# using remote controller (not gaming): 9.61%
# arranging flowers: 7.49%
#    setting table: 4.14%
#           dining: 3.77%
# Top predictions:
#
#          writing: 16.16%
# using remote controller (not gaming): 10.43%
# arranging flowers: 7.40%
#    setting table: 4.63%
#           dining: 3.84%
# Top predictions:
#
#          writing: 17.72%
# using remote controller (not gaming): 13.38%
# arranging flowers: 7.62%
#   using computer: 4.21%
#    setting table: 3.18%
# Top predictions:
#
#          writing: 19.32%
# using remote controller (not gaming): 9.13%
# arranging flowers: 6.89%
#    setting table: 3.36%
#         unboxing: 3.16%
# Top predictions:
#
#          writing: 16.14%
# using remote controller (not gaming): 12.56%
# arranging flowers: 6.52%
#      doing nails: 3.96%
#    playing poker: 3.38%
# Top predictions:
#
#          writing: 20.48%
# using remote controller (not gaming): 10.96%
# arranging flowers: 5.87%
#   using computer: 3.67%
#      doing nails: 3.67%
# Top predictions:
#
#          writing: 17.96%
# using remote controller (not gaming): 8.75%
# arranging flowers: 6.02%
#           dining: 4.40%
#    setting table: 3.88%
# Top predictions:
#
#          writing: 16.59%
# using remote controller (not gaming): 12.13%
# arranging flowers: 7.36%
#    setting table: 3.82%
#  opening present: 2.97%
# Top predictions:
#
#          writing: 16.33%
# using remote controller (not gaming): 10.88%
# arranging flowers: 7.03%
#    setting table: 4.26%
#  opening present: 3.42%
# Top predictions:
#
#          writing: 17.64%
# using remote controller (not gaming): 12.90%
# arranging flowers: 6.70%
#    setting table: 3.58%
#           dining: 2.97%
# Top predictions:
#
#          writing: 16.42%
# using remote controller (not gaming): 12.40%
# arranging flowers: 5.86%
#    playing poker: 3.67%
#      doing nails: 3.55%
# Top predictions:
#
#          writing: 14.39%
# using remote controller (not gaming): 12.30%
# arranging flowers: 6.38%
#      doing nails: 4.25%
#         unboxing: 3.11%
# Top predictions:
#
#          writing: 17.53%
# using remote controller (not gaming): 9.68%
# arranging flowers: 6.25%
#      doing nails: 3.79%
#    playing poker: 3.45%
# Top predictions:
#
#          writing: 17.53%
# using remote controller (not gaming): 12.05%
# arranging flowers: 7.09%
#    setting table: 3.67%
#           dining: 3.24%
# Top predictions:
#
#          writing: 19.78%
# using remote controller (not gaming): 10.25%
# arranging flowers: 5.84%
#   using computer: 3.33%
#      doing nails: 3.13%
# Top predictions:
#
#          writing: 14.55%
# using remote controller (not gaming): 12.44%
# arranging flowers: 9.39%
#    setting table: 4.04%
#           dining: 3.92%
# Top predictions:
#
#          writing: 14.69%
# using remote controller (not gaming): 7.62%
# arranging flowers: 6.73%
#    setting table: 4.21%
#           dining: 4.21%
# Top predictions:
#
#          writing: 16.36%
# using remote controller (not gaming): 10.56%
# arranging flowers: 8.48%
#      doing nails: 3.77%
#  opening present: 3.32%
# Top predictions:
#
#          writing: 13.90%
# using remote controller (not gaming): 11.90%
# arranging flowers: 6.78%
#      doing nails: 4.24%
#   eating carrots: 3.74%
# Top predictions:
#
#          writing: 19.08%
# using remote controller (not gaming): 9.59%
# arranging flowers: 5.82%
#    setting table: 3.64%
#           dining: 3.31%
# Top predictions:
#
#          writing: 15.59%
# using remote controller (not gaming): 11.40%
# arranging flowers: 6.10%
#      doing nails: 4.33%
#   using computer: 3.70%
# Top predictions:
#
#          writing: 18.92%
# using remote controller (not gaming): 11.47%
# arranging flowers: 8.14%
#      doing nails: 3.09%
#         unboxing: 2.99%
# Top predictions:
#
#          writing: 15.69%
# using remote controller (not gaming): 11.12%
# arranging flowers: 5.95%
#      doing nails: 4.09%
#           dining: 3.39%
# Top predictions:
#
#          writing: 18.41%
# using remote controller (not gaming): 10.82%
# arranging flowers: 5.27%
#   using computer: 3.51%
#           dining: 3.51%
# Top predictions:
#
#          writing: 16.58%
# using remote controller (not gaming): 12.51%
# arranging flowers: 5.38%
#          ironing: 3.70%
#      doing nails: 3.70%
# Top predictions:
#
#          writing: 17.96%
# using remote controller (not gaming): 10.89%
# arranging flowers: 5.47%
#           dining: 4.13%
#   using computer: 3.76%
# Top predictions:
#
#          writing: 17.24%
# using remote controller (not gaming): 11.13%
# arranging flowers: 5.77%
#      doing nails: 4.22%
#   eating carrots: 3.85%
# Top predictions:
#
#          writing: 18.57%
# using remote controller (not gaming): 10.92%
# arranging flowers: 5.49%
#      doing nails: 5.00%
#    playing poker: 3.54%
# Top predictions:
#
#          writing: 14.27%
# using remote controller (not gaming): 9.81%
# arranging flowers: 5.95%
#      doing nails: 4.64%
#   eating carrots: 4.22%
# Top predictions:
#
#          writing: 19.65%
# using remote controller (not gaming): 9.58%
# arranging flowers: 7.23%
#   using computer: 3.31%
#      doing nails: 3.21%
# Top predictions:
#
#          writing: 15.38%
# using remote controller (not gaming): 9.93%
# arranging flowers: 6.02%
#      doing nails: 5.15%
#           dining: 3.33%
# Top predictions:
#
#          writing: 15.34%
# using remote controller (not gaming): 10.88%
# arranging flowers: 5.14%
#   eating carrots: 4.53%
#           dining: 4.00%
# Top predictions:
#
#          writing: 14.54%
# using remote controller (not gaming): 10.31%
# arranging flowers: 5.18%
#      doing nails: 3.79%
#           dining: 3.67%
# Top predictions:
#
#          writing: 14.82%
# using remote controller (not gaming): 10.51%
# arranging flowers: 5.29%
#           dining: 3.63%
#      doing nails: 3.01%
# Top predictions:
#
#          writing: 16.52%
# using remote controller (not gaming): 10.66%
# arranging flowers: 4.44%
#           dining: 3.05%
#   using computer: 2.87%
# Top predictions:
#
#          writing: 13.71%
# using remote controller (not gaming): 11.72%
#      doing nails: 4.31%
#           dining: 3.81%
#   eating carrots: 3.69%
# Top predictions:
#
#          writing: 12.94%
# using remote controller (not gaming): 11.07%
# arranging flowers: 6.11%
#   eating carrots: 4.07%
#           dining: 3.82%
# Top predictions:
#
#          writing: 13.17%
# using remote controller (not gaming): 9.34%
#           dining: 4.28%
# arranging flowers: 4.28%
#    setting table: 4.15%
# Top predictions:
#
# using remote controller (not gaming): 12.49%
#          writing: 10.35%
# arranging flowers: 5.21%
#  opening present: 4.05%
#      doing nails: 3.58%
# Top predictions:
#
#          writing: 15.30%
# using remote controller (not gaming): 10.19%
# arranging flowers: 5.45%
#   eating carrots: 4.12%
#   using computer: 3.99%
# Top predictions:
#
# using remote controller (not gaming): 15.01%
#          writing: 13.24%
# arranging flowers: 4.44%
#   using computer: 4.17%
#   eating carrots: 3.46%
# Top predictions:
#
#          writing: 13.61%
# using remote controller (not gaming): 12.01%
# arranging flowers: 7.06%
#    setting table: 3.78%
#      doing nails: 3.66%
# Top predictions:
#
# using remote controller (not gaming): 13.44%
#          writing: 12.24%
# arranging flowers: 4.94%
#    setting table: 4.10%
#      doing nails: 3.97%
# Top predictions:
#
#          writing: 14.42%
# using remote controller (not gaming): 11.95%
#      doing nails: 4.26%
# arranging flowers: 4.26%
#   using computer: 4.13%
# Top predictions:
#
#          writing: 13.73%
# using remote controller (not gaming): 10.05%
# arranging flowers: 5.91%
#           dining: 4.60%
#    setting table: 3.81%
# Top predictions:
#
#          writing: 14.29%
# using remote controller (not gaming): 10.14%
# arranging flowers: 5.10%
#      doing nails: 4.36%
#           dining: 3.50%
# Top predictions:
#
#          writing: 14.34%
# using remote controller (not gaming): 9.55%
# arranging flowers: 4.96%
#    setting table: 4.51%
#           dining: 4.11%
# Top predictions:
#
# using remote controller (not gaming): 14.60%
#          writing: 13.71%
# arranging flowers: 5.04%
#    setting table: 3.93%
#           dining: 3.93%
# Top predictions:
#
#          writing: 13.59%
# using remote controller (not gaming): 13.16%
# arranging flowers: 5.15%
#      doing nails: 4.14%
#    playing poker: 2.85%
# Top predictions:
#
#          writing: 12.55%
# using remote controller (not gaming): 10.74%
#  opening present: 5.23%
# arranging flowers: 4.62%
#           dining: 3.27%
# Top predictions:
#
#          writing: 13.02%
# using remote controller (not gaming): 12.62%
# arranging flowers: 4.36%
#  opening present: 4.23%
#    setting table: 3.62%
# Top predictions:
#
# using remote controller (not gaming): 15.43%
#          writing: 14.05%
# arranging flowers: 5.17%
#    setting table: 3.55%
#  opening present: 3.34%
# Top predictions:
#
#          writing: 12.96%
# using remote controller (not gaming): 10.09%
# arranging flowers: 4.62%
#    setting table: 3.95%
#      doing nails: 3.95%
# Top predictions:
#
#          writing: 13.84%
# using remote controller (not gaming): 10.45%
#  opening present: 3.61%
#      doing nails: 3.39%
# arranging flowers: 3.39%
# Top predictions:
#
# using remote controller (not gaming): 14.33%
#          writing: 13.46%
# arranging flowers: 4.95%
#  opening present: 3.51%
#           dining: 3.20%
# Top predictions:
#
#          writing: 15.33%
# using remote controller (not gaming): 14.40%
# arranging flowers: 6.39%
#    setting table: 3.53%
#  opening present: 3.21%
# Top predictions:
#
#          writing: 14.29%
# using remote controller (not gaming): 13.85%
# arranging flowers: 4.79%
#    setting table: 3.85%
#           dining: 3.85%
# Top predictions:
#
#          writing: 14.34%
# using remote controller (not gaming): 12.27%
# arranging flowers: 4.38%
#      doing nails: 3.63%
#  opening present: 3.30%
# Top predictions:
#
#          writing: 13.85%
# using remote controller (not gaming): 11.14%
# arranging flowers: 4.10%
#   eating carrots: 3.62%
#      doing nails: 3.62%
# Top predictions:
#
#          writing: 12.23%
# using remote controller (not gaming): 11.85%
#   eating carrots: 6.54%
#    playing poker: 4.94%
# arranging flowers: 4.36%
# Top predictions:
#
#  opening present: 9.72%
#       bartending: 7.57%
#       auctioning: 5.20%
#         krumping: 4.74%
# using remote controller (not gaming): 4.05%
# Top predictions:
#
#  opening present: 15.82%
#       bartending: 4.68%
# using remote controller (not gaming): 3.76%
#         krumping: 3.42%
#       auctioning: 2.66%
# Top predictions:
#
#  opening present: 10.08%
#         krumping: 7.15%
# jumpstyle dancing: 5.57%
#     air drumming: 5.40%
#    robot dancing: 4.76%
# Top predictions:
#
#     air drumming: 12.03%
# moving furniture: 5.01%
#          ironing: 4.29%
#     front raises: 4.29%
#  opening present: 3.56%
# Top predictions:
#
#    setting table: 30.00%
#           dining: 12.51%
#          writing: 11.75%
# moving furniture: 7.13%
#  opening present: 2.31%
# Top predictions:
#
#    setting table: 32.01%
#           dining: 15.60%
#          writing: 11.41%
# moving furniture: 5.74%
#  opening present: 2.11%
# Top predictions:
#
#    setting table: 28.52%
#          writing: 13.05%
#           dining: 11.52%
# moving furniture: 7.67%
#  opening present: 2.20%
# Top predictions:
#
#    setting table: 28.74%
#          writing: 12.76%
#           dining: 11.25%
# moving furniture: 7.27%
#            situp: 2.51%
# Top predictions:
#
#           dining: 35.33%
#    setting table: 34.23%
#  opening present: 4.78%
# moving furniture: 2.33%
#            situp: 1.70%
# Top predictions:
#
#           dining: 35.72%
#    setting table: 34.62%
# moving furniture: 4.27%
#  opening present: 2.75%
#            situp: 2.02%
# Top predictions:
#
#           dining: 37.35%
#    setting table: 30.00%
# moving furniture: 4.32%
#            situp: 2.04%
#  opening present: 2.04%
# Top predictions:
#
#    setting table: 28.93%
#           dining: 28.03%
# moving furniture: 5.70%
#  opening present: 3.35%
#          writing: 2.86%
# Top predictions:
#
#    setting table: 36.11%
#           dining: 30.88%
# moving furniture: 4.31%
#  opening present: 2.78%
#            situp: 1.85%
# Top predictions:
#
#    setting table: 37.87%
#           dining: 28.59%
# moving furniture: 5.12%
#  opening present: 2.83%
#            situp: 1.83%
# Top predictions:
#
#           dining: 35.86%
#    setting table: 33.69%
# moving furniture: 4.71%
#  opening present: 2.15%
#            situp: 2.02%
# Top predictions:
#
#    setting table: 32.54%
#           dining: 21.68%
# moving furniture: 6.82%
#  opening present: 6.21%
#            situp: 2.93%
# Top predictions:
#
#    setting table: 30.83%
#           dining: 26.37%
# moving furniture: 5.04%
#  opening present: 4.17%
#            situp: 2.45%
# Top predictions:
#
#    setting table: 31.13%
#           dining: 29.25%
# moving furniture: 6.52%
#            situp: 2.40%
#  opening present: 2.19%
# Top predictions:
#
#           dining: 40.11%
#    setting table: 32.23%
# moving furniture: 3.40%
#  opening present: 1.88%
#            situp: 1.76%
# Top predictions:
#
#    setting table: 31.79%
#           dining: 30.81%
# moving furniture: 4.87%
#  opening present: 3.25%
#            situp: 2.45%
# Top predictions:
#
#           dining: 33.20%
#    setting table: 33.20%
# moving furniture: 5.77%
#            situp: 2.19%
#  opening present: 1.99%
# Top predictions:
#
#    setting table: 27.86%
#           dining: 26.98%
# moving furniture: 6.41%
#  opening present: 3.22%
#            situp: 3.03%
# Top predictions:
#
#           dining: 32.64%
#    setting table: 32.64%
# moving furniture: 4.28%
#  opening present: 2.85%
#            situp: 2.52%
# Top predictions:
#
#    setting table: 36.30%
#           dining: 26.56%
# moving furniture: 5.57%
#          writing: 2.89%
#  opening present: 2.80%
# Top predictions:
#
#    setting table: 32.57%
#           dining: 27.00%
# moving furniture: 5.15%
#  opening present: 2.76%
#            situp: 2.51%
# Top predictions:
#
#    setting table: 34.69%
#           dining: 27.88%
# moving furniture: 4.70%
#  opening present: 4.02%
#            situp: 2.22%
# Top predictions:
#
#    setting table: 32.35%
#           dining: 30.40%
# moving furniture: 4.81%
#  opening present: 3.31%
#            situp: 2.49%
# Top predictions:
#
#    setting table: 35.16%
#           dining: 34.08%
# moving furniture: 4.33%
#  opening present: 2.55%
#            situp: 1.86%
# Top predictions:
#
#    setting table: 36.62%
#           dining: 34.40%
#  opening present: 3.52%
# moving furniture: 3.01%
#            situp: 1.71%
# Top predictions:
#
#    setting table: 35.25%
#           dining: 30.15%
# moving furniture: 4.08%
#  opening present: 3.28%
#            situp: 2.25%
# Top predictions:
#
#    setting table: 32.84%
#           dining: 26.39%
# moving furniture: 6.67%
#  opening present: 4.44%
#            situp: 2.45%
# Top predictions:
#
#    setting table: 36.23%
#           dining: 31.96%
# moving furniture: 3.16%
#  opening present: 3.07%
#          writing: 2.24%
# Top predictions:
#
#    setting table: 32.42%
#           dining: 26.05%
# moving furniture: 5.63%
#  opening present: 2.92%
#          writing: 2.66%
# Top predictions:
#
#           dining: 32.84%
#    setting table: 30.83%
# moving furniture: 4.73%
#  opening present: 2.61%
#            situp: 2.31%
# Top predictions:
#
#    setting table: 30.76%
#           dining: 23.96%
# moving furniture: 6.87%
#  opening present: 3.67%
#            situp: 3.24%
# Top predictions:
#
#           dining: 31.05%
#    setting table: 30.10%
# moving furniture: 4.91%
#  opening present: 3.71%
#            situp: 2.25%
# Top predictions:
#
#    setting table: 34.86%
#           dining: 29.81%
# moving furniture: 5.18%
#  opening present: 2.61%
#            situp: 1.91%
# Top predictions:
#
#    setting table: 31.69%
#           dining: 29.79%
# moving furniture: 5.18%
#  opening present: 2.86%
#            situp: 2.44%
# Top predictions:
#
#    setting table: 35.91%
#           dining: 33.74%
# moving furniture: 4.86%
#  opening present: 2.60%
#            situp: 1.90%
# Top predictions:
#
#    setting table: 31.96%
#           dining: 27.32%
# moving furniture: 7.59%
#  opening present: 2.54%
#            situp: 2.31%
# Top predictions:
#
#    setting table: 32.01%
#           dining: 24.16%
# moving furniture: 6.50%
#  opening present: 3.59%
#          writing: 2.71%
# Top predictions:
#
#    setting table: 37.18%
#           dining: 20.53%
# moving furniture: 6.07%
#  opening present: 3.80%
#          writing: 3.68%
# Top predictions:
#
#    setting table: 32.40%
#           dining: 23.69%
# moving furniture: 6.58%
#          writing: 3.41%
#            situp: 3.01%
# Top predictions:
#
#    setting table: 34.72%
#           dining: 28.78%
# moving furniture: 4.02%
#  opening present: 3.23%
#            situp: 2.22%
# Top predictions:
#
#    setting table: 37.23%
#           dining: 36.08%
#  opening present: 2.61%
# moving furniture: 2.31%
#            situp: 1.59%
# Top predictions:
#
#    setting table: 33.69%
#           dining: 27.93%
# moving furniture: 4.28%
#  opening present: 3.34%
#            situp: 2.52%
# Top predictions:
#
#    setting table: 34.81%
#           dining: 26.29%
# moving furniture: 5.18%
#          writing: 3.14%
#  opening present: 2.60%
# Top predictions:
#
#    setting table: 34.47%
#           dining: 26.86%
# moving furniture: 5.29%
#  opening present: 3.52%
#            situp: 2.50%
# Top predictions:
#
#    setting table: 36.38%
#           dining: 30.15%
# moving furniture: 5.24%
#            situp: 2.55%
#          writing: 2.40%
# Top predictions:
#
#    setting table: 30.98%
#           dining: 22.66%
# moving furniture: 8.08%
#          writing: 3.70%
#            situp: 2.79%
# Top predictions:
#
#    setting table: 39.79%
#           dining: 29.10%
# moving furniture: 4.46%
#  opening present: 2.39%
#          writing: 2.04%
# Top predictions:
#
#           dining: 34.84%
#    setting table: 27.12%
# moving furniture: 4.71%
#  opening present: 3.24%
#            situp: 2.30%
# Top predictions:
#
#    setting table: 30.59%
#           dining: 29.66%
# moving furniture: 5.15%
#  opening present: 3.33%
#          writing: 2.67%
# Top predictions:
#
#  opening present: 17.09%
#     air drumming: 8.87%
#         krumping: 7.12%
#       making tea: 5.55%
#    juggling fire: 3.37%
# Top predictions:
#
#          ironing: 12.13%
#  opening present: 9.45%
#           dining: 6.10%
#    setting table: 5.38%
# moving furniture: 4.90%
# Top predictions:
#
#           dining: 40.36%
#    setting table: 33.47%
# moving furniture: 2.66%
#          writing: 1.95%
#  opening present: 1.77%
# Top predictions:
#
#           dining: 33.64%
#    setting table: 32.62%
# moving furniture: 5.85%
#  opening present: 2.36%
#            situp: 2.22%
# Top predictions:
#
#           dining: 37.92%
#    setting table: 31.42%
# moving furniture: 4.97%
#  opening present: 2.28%
#            situp: 1.83%
# Top predictions:
#
#    setting table: 35.86%
#           dining: 29.74%
# moving furniture: 4.42%
#  opening present: 3.55%
#            situp: 1.90%
# Top predictions:
#
#    setting table: 39.04%
#           dining: 23.68%
# moving furniture: 4.81%
#          writing: 3.11%
#  opening present: 2.35%
# Top predictions:
#
#    setting table: 37.74%
#           dining: 33.33%
# moving furniture: 3.74%
#  opening present: 3.20%
#            situp: 1.66%
# Top predictions:
#
#           dining: 35.82%
#    setting table: 33.64%
# moving furniture: 4.14%
#  opening present: 2.36%
#            situp: 2.08%
# Top predictions:
#
#    setting table: 36.33%
#           dining: 27.42%
# moving furniture: 6.93%
#  opening present: 2.71%
#          writing: 2.05%
# Top predictions:
#
#    setting table: 31.84%
#           dining: 29.00%
# moving furniture: 6.08%
#  opening present: 3.15%
#          writing: 2.46%
# Top predictions:
#
#  opening present: 12.08%
#          ironing: 10.34%
#           dining: 6.08%
#    setting table: 5.20%
# using remote controller (not gaming): 4.59%
# Top predictions:
#
#           dining: 14.33%
#  opening present: 6.56%
#    setting table: 5.79%
#          ironing: 4.65%
#    making a cake: 3.00%
# Top predictions:
#
#           dining: 10.56%
#  opening present: 9.61%
# moving furniture: 6.61%
#    setting table: 4.83%
#    making a cake: 3.77%
# Top predictions:
#
#       making tea: 22.45%
#    making a cake: 9.66%
#          ironing: 7.29%
#   washing dishes: 6.04%
#  opening present: 6.04%
# Top predictions:
#
#   washing dishes: 15.34%
#       making tea: 13.54%
#     air drumming: 8.22%
#    making a cake: 3.88%
#         krumping: 3.53%
# Top predictions:
#
#  opening present: 24.82%
#           dining: 11.36%
#    setting table: 6.08%
# blowing out candles: 5.71%
#    making a cake: 2.53%
# Top predictions:
#
#           dining: 36.96%
#    setting table: 36.96%
# moving furniture: 3.13%
#  opening present: 3.03%
#            situp: 1.68%
# Top predictions:
#
#           dining: 37.13%
#    setting table: 31.76%
#  opening present: 3.68%
# moving furniture: 3.14%
#            situp: 2.23%
# Top predictions:
#
#    setting table: 32.45%
#           dining: 31.47%
# moving furniture: 4.68%
#  opening present: 2.66%
#            situp: 2.01%
# Top predictions:
#
#    setting table: 33.76%
#           dining: 28.88%
# moving furniture: 4.03%
#  opening present: 3.45%
#            situp: 2.03%
# Top predictions:
#
#           dining: 42.04%
#    setting table: 32.74%
# moving furniture: 2.69%
#  opening present: 1.85%
#            situp: 1.39%
# Top predictions:
#
#    setting table: 38.82%
#           dining: 29.30%
#  opening present: 4.22%
# moving furniture: 2.90%
#            situp: 1.82%
# Top predictions:
#
#    setting table: 38.45%
#           dining: 36.13%
# moving furniture: 2.87%
#  opening present: 2.54%
#            situp: 1.49%
# Top predictions:
#
#    setting table: 33.98%
#           dining: 30.96%
#  opening present: 3.58%
# moving furniture: 3.47%
#            situp: 2.24%
# Top predictions:
#
#    setting table: 39.70%
#           dining: 38.48%
# moving furniture: 2.97%
#  opening present: 1.86%
#            situp: 1.16%
# Top predictions:
#
#           dining: 39.65%
#    setting table: 38.43%
#  opening present: 2.38%
# moving furniture: 2.17%
#            situp: 1.36%
# Top predictions:
#
#    setting table: 35.40%
#           dining: 28.44%
#  opening present: 4.50%
# moving furniture: 3.29%
#            situp: 2.06%
# Top predictions:
#
#    setting table: 35.40%
#           dining: 34.33%
# moving furniture: 3.62%
#  opening present: 2.82%
#            situp: 1.66%
# Top predictions:
#
#           dining: 38.65%
#    setting table: 31.05%
# moving furniture: 3.59%
#  opening present: 2.80%
#            situp: 1.70%
# Top predictions:
#
#           dining: 37.84%
#    setting table: 33.40%
# moving furniture: 2.83%
#            situp: 1.94%
#  opening present: 1.88%
# Top predictions:
#
#           dining: 37.43%
#    setting table: 35.16%
#  opening present: 2.80%
# moving furniture: 2.71%
#            situp: 1.86%
# Top predictions:
#
#    setting table: 39.23%
#           dining: 30.54%
#  opening present: 3.65%
# moving furniture: 3.32%
#            situp: 1.67%
# Top predictions:
#
#           dining: 37.08%
#    setting table: 37.08%
# moving furniture: 2.95%
#  opening present: 1.90%
#            situp: 1.48%
# Top predictions:
#
#    setting table: 38.28%
#           dining: 30.76%
# moving furniture: 4.16%
#  opening present: 2.86%
#            situp: 1.79%
# Top predictions:
#
#           dining: 41.60%
#    setting table: 33.45%
# moving furniture: 3.52%
#  opening present: 2.01%
#            situp: 1.42%
# Top predictions:
#
#           dining: 39.18%
#    setting table: 36.82%
#  opening present: 2.58%
# moving furniture: 2.43%
#            situp: 1.57%
# Top predictions:
#
#           dining: 33.37%
#    setting table: 31.35%
# moving furniture: 4.52%
#  opening present: 2.74%
#            situp: 2.27%
# Top predictions:
#
#    setting table: 37.57%
#           dining: 35.30%
# moving furniture: 4.78%
#  opening present: 1.99%
#            situp: 1.46%
# Top predictions:
#
#    setting table: 29.61%
#           dining: 28.71%
# moving furniture: 4.84%
#  opening present: 3.43%
#          writing: 2.67%
# Top predictions:
#
#    setting table: 32.08%
#           dining: 29.22%
# moving furniture: 5.58%
#  opening present: 3.08%
#            situp: 2.25%
# Top predictions:
#
#    setting table: 35.82%
#           dining: 24.61%
# moving furniture: 4.70%
#  opening present: 4.41%
#            situp: 2.44%
# Top predictions:
#
#    setting table: 34.03%
#           dining: 29.13%
# moving furniture: 5.22%
#  opening present: 3.70%
#            situp: 1.98%
# Top predictions:
#
#    setting table: 32.96%
#           dining: 24.11%
# moving furniture: 6.49%
#  opening present: 4.46%
#            situp: 2.24%
# Top predictions:
#
#    setting table: 30.86%
#           dining: 19.92%
# moving furniture: 6.27%
#  opening present: 3.92%
#            situp: 3.25%
# Top predictions:
#
#    setting table: 27.71%
#           dining: 26.86%
# moving furniture: 5.81%
#  opening present: 3.75%
#            situp: 2.74%
# Top predictions:
#
#    setting table: 30.49%
#           dining: 27.76%
# moving furniture: 5.82%
#          writing: 3.12%
#  opening present: 3.12%
# Top predictions:
#
#    setting table: 35.03%
#           dining: 29.98%
# moving furniture: 4.74%
#  opening present: 2.46%
#            situp: 2.04%
# Top predictions:
#
#    setting table: 33.98%
#           dining: 21.94%
# moving furniture: 5.55%
#  opening present: 4.19%
#          writing: 2.79%
# Top predictions:
#
#    setting table: 36.96%
#           dining: 27.05%
# moving furniture: 4.55%
#  opening present: 3.90%
#            situp: 1.96%
# Top predictions:
#
#    setting table: 34.30%
#           dining: 30.27%
# moving furniture: 3.85%
#  opening present: 3.50%
#            situp: 1.88%
# Top predictions:
#
#    setting table: 30.91%
#           dining: 25.61%
# moving furniture: 5.72%
#  opening present: 3.06%
#          writing: 2.79%
# Top predictions:
#
#    setting table: 34.57%
#           dining: 31.47%
# moving furniture: 3.32%
#  opening present: 3.02%
#          writing: 2.28%
# Top predictions:
#
#    setting table: 31.49%
#           dining: 26.10%
# moving furniture: 4.83%
#          writing: 3.42%
#            situp: 2.58%
# Top predictions:
#
#    setting table: 30.44%
#           dining: 19.67%
# moving furniture: 7.01%
#  opening present: 3.99%
#            situp: 2.75%
# Top predictions:
#
#    setting table: 33.72%
#           dining: 22.45%
# moving furniture: 7.52%
#  opening present: 4.42%
#            situp: 2.52%
# Top predictions:
#
#    setting table: 28.83%
#           dining: 13.62%
# moving furniture: 7.76%
#          writing: 4.42%
#  opening present: 4.42%
# Top predictions:
#
#    setting table: 36.13%
#           dining: 29.96%
#  opening present: 4.45%
# moving furniture: 3.81%
#            situp: 1.86%
# Top predictions:
#
#           dining: 33.72%
#    setting table: 33.72%
# moving furniture: 4.42%
#  opening present: 2.44%
#            situp: 1.84%
# Top predictions:
#
#    setting table: 37.82%
#           dining: 25.98%
# moving furniture: 4.96%
#          writing: 2.66%
#  opening present: 2.49%
# Top predictions:
#
#    setting table: 31.35%
#           dining: 27.66%
# moving furniture: 4.96%
#  opening present: 3.41%
#            situp: 2.57%
# Top predictions:
#
#    setting table: 34.57%
#           dining: 27.78%
# moving furniture: 6.40%
#  opening present: 2.75%
#            situp: 2.21%
# Top predictions:
#
#    setting table: 33.25%
#           dining: 31.23%
# moving furniture: 5.43%
#  opening present: 2.64%
#            situp: 1.93%
# Top predictions:
#
#           dining: 33.86%
#    setting table: 31.81%
# moving furniture: 3.92%
#  opening present: 3.05%
#            situp: 2.10%
# Top predictions:
#
#    setting table: 28.08%
#           dining: 24.77%
# moving furniture: 6.07%
#  opening present: 3.35%
#          writing: 2.78%
# Top predictions:
#
#    setting table: 33.35%
#           dining: 22.92%
# moving furniture: 6.99%
#  opening present: 2.91%
#            situp: 2.65%
# Top predictions:
#
#    setting table: 31.40%
#           dining: 24.46%
# moving furniture: 5.81%
#  opening present: 4.12%
#            situp: 2.42%
# Top predictions:
#
#    setting table: 35.01%
#           dining: 29.03%
# moving furniture: 4.18%
#  opening present: 3.36%
#            situp: 2.04%
# Top predictions:
#
#    setting table: 32.52%
#           dining: 26.95%
# moving furniture: 6.61%
#  opening present: 2.84%
#            situp: 2.51%
# Top predictions:
#
#    setting table: 33.59%
#           dining: 30.59%
# moving furniture: 5.00%
#  opening present: 2.51%
#            situp: 2.22%
# Top predictions:
#
#    setting table: 30.79%
#           dining: 22.52%
# moving furniture: 6.66%
#  opening present: 5.18%
#            situp: 2.78%
# Top predictions:
#
#           dining: 32.79%
#    setting table: 32.79%
# moving furniture: 5.35%
#  opening present: 3.05%
#            situp: 1.91%
# Top predictions:
#
#    setting table: 31.57%
#           dining: 24.58%
# moving furniture: 4.69%
#  opening present: 4.14%
#          writing: 2.94%
# Top predictions:
#
#    setting table: 34.72%
#           dining: 23.86%
# moving furniture: 5.33%
#  opening present: 3.33%
#            situp: 2.60%
# Top predictions:
#
#    setting table: 35.28%
#           dining: 23.50%
# moving furniture: 7.40%
#  opening present: 2.99%
#          writing: 2.90%
# Top predictions:
#
#    setting table: 33.37%
#           dining: 22.94%
#  opening present: 5.28%
# moving furniture: 4.96%
#            situp: 2.34%
# Top predictions:
#
#    setting table: 29.13%
#           dining: 26.51%
# moving furniture: 6.11%
#  opening present: 3.59%
#          writing: 2.88%
# Top predictions:
#
#    setting table: 33.89%
#           dining: 23.29%
#  opening present: 4.88%
# moving furniture: 4.88%
#            situp: 2.46%
# Top predictions:
#
#    setting table: 33.74%
#           dining: 23.19%
# moving furniture: 5.51%
#  opening present: 3.67%
#            situp: 2.52%
# Top predictions:
#
#    setting table: 32.69%
#           dining: 18.05%
# moving furniture: 8.26%
#  opening present: 3.90%
#            situp: 2.95%
# Top predictions:
#
#           dining: 29.27%
#    setting table: 28.37%
# moving furniture: 5.95%
#            situp: 2.72%
#  opening present: 2.40%
# Top predictions:
#
#    setting table: 35.52%
#           dining: 25.20%
#  opening present: 5.28%
# moving furniture: 4.81%
#            situp: 2.27%
# Top predictions:
#
#    setting table: 33.62%
#           dining: 23.10%
# moving furniture: 6.02%
#  opening present: 5.15%
#            situp: 2.43%
# Top predictions:
#
#    setting table: 32.50%
#           dining: 28.69%
# moving furniture: 4.54%
#  opening present: 3.22%
#          writing: 2.43%
# Top predictions:
#
#    setting table: 34.01%
#           dining: 24.12%
# moving furniture: 4.90%
#  opening present: 4.19%
#          writing: 2.17%
# Top predictions:
#
#    setting table: 36.21%
#           dining: 21.95%
# moving furniture: 6.29%
#  opening present: 3.81%
#            situp: 2.71%
# Top predictions:
#
#    setting table: 29.76%
#           dining: 26.27%
# moving furniture: 5.34%
#  opening present: 3.91%
#          writing: 2.95%
# Top predictions:
#
#    setting table: 35.96%
#           dining: 26.29%
# moving furniture: 5.34%
#  opening present: 2.77%
#            situp: 2.30%
# Top predictions:
#
#    setting table: 36.23%
#           dining: 30.03%
#  opening present: 5.06%
# moving furniture: 3.07%
#            situp: 1.80%
# Top predictions:
#
#    setting table: 34.52%
#           dining: 25.24%
# moving furniture: 5.13%
#  opening present: 3.75%
#            situp: 2.28%
# Top predictions:
#
#    setting table: 33.37%
#           dining: 30.40%
# moving furniture: 5.62%
#  opening present: 2.66%
#            situp: 2.01%
# Top predictions:
#
#    setting table: 31.96%
#           dining: 30.03%
# moving furniture: 5.73%
#  opening present: 3.27%
#            situp: 2.04%
# Top predictions:
#
#    setting table: 34.38%
#           dining: 25.95%
# moving furniture: 6.16%
#          writing: 3.10%
#            situp: 2.65%
# Top predictions:
#
#    setting table: 35.28%
#           dining: 25.02%
# moving furniture: 7.17%
#  opening present: 3.08%
#            situp: 2.26%
# Top predictions:
#
#         krumping: 23.02%
#     air drumming: 8.21%
#    salsa dancing: 7.47%
#  opening present: 4.82%
# jumpstyle dancing: 4.68%
# Top predictions:
#
#          tai chi: 8.54%
#         krumping: 8.28%
#   clean and jerk: 6.45%
#     air drumming: 5.51%
#   sword fighting: 4.29%
# Top predictions:
#
#           dining: 15.54%
#  opening present: 10.68%
#    setting table: 6.90%
#    making a cake: 4.32%
#       making tea: 3.58%
# Top predictions:
#
#    making a cake: 7.30%
# decorating the christmas tree: 7.30%
#  opening present: 5.51%
#      waxing back: 5.51%
#          ironing: 4.71%
# Top predictions:
#
# moving furniture: 8.47%
#  opening present: 8.21%
#           dining: 6.81%
#          ironing: 6.20%
#      waxing back: 4.83%
# Top predictions:
#
#           dining: 17.09%
#    setting table: 17.09%
# moving furniture: 8.59%
#  opening present: 7.35%
#    playing poker: 4.32%
# Top predictions:
#
#    setting table: 25.00%
#           dining: 22.77%
#  opening present: 6.32%
# moving furniture: 4.48%
#            situp: 2.64%
# Top predictions:
#
#           dining: 29.37%
#    setting table: 20.19%
# moving furniture: 5.97%
#  opening present: 3.40%
#      waxing back: 2.65%
# Top predictions:
#
#           dining: 17.75%
#    setting table: 16.16%
#  opening present: 5.59%
# moving furniture: 5.41%
#          ironing: 3.96%
# Top predictions:
#
#           dining: 21.15%
#    setting table: 15.48%
# moving furniture: 7.31%
#  opening present: 6.45%
#    playing poker: 4.04%
# Top predictions:
#
#  opening present: 11.98%
#           dining: 11.25%
#    setting table: 10.57%
# moving furniture: 6.21%
#          ironing: 4.41%
# Top predictions:
#
#     air drumming: 10.85%
#         krumping: 6.58%
#  opening present: 5.45%
# moving furniture: 3.87%
#   clean and jerk: 3.87%
# Top predictions:
#
#          tai chi: 28.91%
#    belly dancing: 9.39%
# dancing charleston: 8.28%
#         krumping: 8.03%
# dancing macarena: 5.02%
# Top predictions:
#
#           dining: 23.40%
#  opening present: 16.60%
#    setting table: 13.76%
# moving furniture: 3.07%
#       barbequing: 2.25%
# Top predictions:
#
#           dining: 28.98%
#    setting table: 23.29%
# moving furniture: 8.84%
#  opening present: 3.35%
#            situp: 2.70%
# Top predictions:
#
#           dining: 26.49%
#    setting table: 25.68%
# moving furniture: 8.87%
#  opening present: 2.97%
#            situp: 2.39%
# Top predictions:
#
#    setting table: 29.15%
#           dining: 27.39%
# moving furniture: 7.37%
#  opening present: 4.20%
#            situp: 2.11%
# Top predictions:
#
#           dining: 30.03%
#    setting table: 25.68%
# moving furniture: 8.61%
#  opening present: 3.37%
#            situp: 2.32%
# Top predictions:
#
#           dining: 35.64%
#    setting table: 25.27%
# moving furniture: 5.82%
#  opening present: 4.26%
#            situp: 2.07%
# Top predictions:
#
#    setting table: 26.12%
#           dining: 20.35%
# moving furniture: 10.89%
#  opening present: 3.43%
#            situp: 3.02%
# Top predictions:
#
#           dining: 30.15%
#    setting table: 24.99%
# moving furniture: 8.91%
#  opening present: 3.18%
#            situp: 2.63%
# Top predictions:
#
#           dining: 30.49%
#    setting table: 28.64%
# moving furniture: 6.39%
#  opening present: 3.31%
#            situp: 2.43%
# Top predictions:
#
#           dining: 24.93%
#    setting table: 24.93%
# moving furniture: 12.15%
#  opening present: 3.27%
#            situp: 2.47%
# Top predictions:
#
#    setting table: 23.28%
#           dining: 21.86%
# moving furniture: 11.35%
#            situp: 2.96%
#  opening present: 2.96%
# Top predictions:
#
#     air drumming: 9.44%
#         krumping: 9.15%
#  opening present: 8.33%
#    salsa dancing: 7.59%
#    brushing hair: 4.06%
# Top predictions:
#
#    making a cake: 16.50%
#         krumping: 8.04%
#       making tea: 6.46%
#     air drumming: 5.53%
#   clean and jerk: 4.31%
# Top predictions:
#
#    making a cake: 34.28%
# decorating the christmas tree: 9.22%
#       making tea: 5.42%
#          ironing: 5.42%
# making a sandwich: 5.26%
# Top predictions:
#
#          ironing: 27.20%
#    making a cake: 17.02%
#     making sushi: 7.79%
#       making tea: 7.09%
#     making pizza: 6.07%
# Top predictions:
#
#           dining: 20.90%
#  opening present: 7.69%
#    setting table: 5.62%
#    playing poker: 5.45%
#   eating carrots: 2.42%
# Top predictions:
#
#           dining: 10.91%
#  opening present: 9.63%
#    playing poker: 8.23%
#      doing nails: 7.27%
# using remote controller (not gaming): 6.83%
# Top predictions:
#
#           dining: 15.19%
#          writing: 9.80%
#    playing poker: 6.13%
#    setting table: 5.25%
#  opening present: 4.78%
# Top predictions:
#
#           dining: 10.55%
# using remote controller (not gaming): 7.97%
#  opening present: 7.97%
#    playing poker: 7.03%
#          writing: 5.14%
# Top predictions:
#
#           dining: 11.33%
# using remote controller (not gaming): 7.55%
#          writing: 7.09%
#  opening present: 5.70%
#      doing nails: 5.70%
# Top predictions:
#
#           dining: 17.40%
# using remote controller (not gaming): 6.81%
#      doing nails: 6.01%
#    playing poker: 5.47%
# ...
#    setting table: 6.35%
# arranging flowers: 6.35%
#   using computer: 4.36%
# Top predictions:
#
#          writing: 18.05%
# using remote controller (not gaming): 9.08%
# arranging flowers: 7.29%
#    setting table: 6.24%
#           dining: 4.86%
# Top predictions:
#
#          writing: 17.75%
# using remote controller (not gaming): 11.46%
# arranging flowers: 6.14%
#    setting table: 4.63%
#   using computer: 4.22%
# Top predictions:
#
#          writing: 15.06%
# using remote controller (not gaming): 9.73%
# arranging flowers: 6.90%
#    setting table: 6.68%
#           dining: 5.54%
# Top predictions:
#
#          writing: 19.17%
# using remote controller (not gaming): 9.34%
# arranging flowers: 7.51%
#    setting table: 6.42%
#           dining: 4.70%
# Top predictions:
#
#          writing: 18.40%
# using remote controller (not gaming): 10.16%
# arranging flowers: 7.67%
#   using computer: 5.61%
#    setting table: 4.24%
# Top predictions:
#
#          writing: 16.85%
# using remote controller (not gaming): 10.22%
# arranging flowers: 7.24%
#    setting table: 6.20%
#   using computer: 4.83%
# Top predictions:
#
#          writing: 19.08%
# using remote controller (not gaming): 12.32%
# arranging flowers: 7.24%
#   using computer: 5.30%
#    setting table: 4.98%
# Top predictions:
#
#          writing: 16.19%
# using remote controller (not gaming): 9.22%
# arranging flowers: 8.40%
#    setting table: 6.34%
#           dining: 4.35%
# Top predictions:
#
#          writing: 15.76%
# using remote controller (not gaming): 12.27%
# arranging flowers: 7.21%
#    setting table: 6.17%
#   using computer: 4.66%
# Top predictions:
#
#          writing: 18.87%
# using remote controller (not gaming): 14.70%
# arranging flowers: 7.63%
#   using computer: 6.13%
#    setting table: 4.63%
# Top predictions:
#
#          writing: 17.52%
# using remote controller (not gaming): 12.04%
# arranging flowers: 8.81%
#    setting table: 6.24%
#   using computer: 5.34%
# Top predictions:
#
#          writing: 20.72%
# using remote controller (not gaming): 11.44%
# arranging flowers: 8.37%
#   using computer: 5.40%
#    setting table: 4.08%
# Top predictions:
#
#          writing: 19.10%
# using remote controller (not gaming): 9.91%
# arranging flowers: 6.60%
#    setting table: 5.14%
#   using computer: 4.40%
# Top predictions:
#
#          writing: 15.39%
# using remote controller (not gaming): 10.92%
# arranging flowers: 6.42%
#    setting table: 5.84%
#           dining: 4.14%
# Top predictions:
#
#          writing: 16.63%
# using remote controller (not gaming): 8.62%
#    setting table: 6.93%
# arranging flowers: 6.31%
#           dining: 5.93%
# Top predictions:
#
#          writing: 15.87%
# using remote controller (not gaming): 10.57%
# arranging flowers: 8.23%
#   using computer: 5.15%
#    setting table: 4.84%
# Top predictions:
#
#          writing: 20.97%
# using remote controller (not gaming): 13.12%
# arranging flowers: 7.71%
#   using computer: 6.01%
#    setting table: 4.40%
# Top predictions:
#
#          writing: 17.29%
# using remote controller (not gaming): 11.88%
# arranging flowers: 6.77%
#   using computer: 5.11%
#    setting table: 4.24%
# Top predictions:
#
#          writing: 18.47%
# using remote controller (not gaming): 10.86%
# arranging flowers: 8.72%
#   using computer: 6.19%
#    setting table: 5.13%
# Top predictions:
#
#          writing: 20.57%
# using remote controller (not gaming): 10.02%
#    setting table: 7.33%
# arranging flowers: 7.10%
#   using computer: 4.45%
# Top predictions:
#
#          writing: 15.84%
# using remote controller (not gaming): 13.13%
# arranging flowers: 9.61%
#    setting table: 4.99%
#   using computer: 4.54%
# Top predictions:
#
#          writing: 18.25%
# using remote controller (not gaming): 11.78%
# arranging flowers: 6.92%
#    setting table: 5.74%
#   using computer: 5.23%
# Top predictions:
#
#          writing: 15.55%
# using remote controller (not gaming): 14.16%
# arranging flowers: 7.82%
#   using computer: 5.54%
#    setting table: 5.54%
# Top predictions:
#
#          writing: 20.30%
# using remote controller (not gaming): 11.57%
#   using computer: 5.82%
#    setting table: 5.64%
# arranging flowers: 5.46%
# Top predictions:
#
#          writing: 15.59%
# using remote controller (not gaming): 13.76%
# arranging flowers: 8.88%
#   using computer: 5.06%
#    setting table: 4.75%
# Top predictions:
#
#          writing: 16.77%
# using remote controller (not gaming): 8.70%
# arranging flowers: 7.44%
#    setting table: 7.21%
#   using computer: 5.44%
# Top predictions:
#
#          writing: 14.34%
# using remote controller (not gaming): 13.06%
# arranging flowers: 9.26%
#    setting table: 5.80%
#   using computer: 4.66%
# Top predictions:
#
#          writing: 18.04%
# using remote controller (not gaming): 13.62%
# arranging flowers: 8.01%
#   using computer: 6.04%
#    setting table: 4.71%
# Top predictions:
#
#          writing: 16.78%
# using remote controller (not gaming): 10.50%
# arranging flowers: 6.57%
#    setting table: 5.62%
#   using computer: 4.66%
# Top predictions:
#
#          writing: 15.23%
# using remote controller (not gaming): 13.44%
# arranging flowers: 7.20%
#    setting table: 6.55%
#   using computer: 5.10%
# Top predictions:
#
#          writing: 17.29%
# using remote controller (not gaming): 10.49%
#    setting table: 7.67%
# arranging flowers: 7.43%
#           dining: 4.24%
# Top predictions:
#
#          writing: 17.76%
# using remote controller (not gaming): 8.65%
#    setting table: 6.14%
# arranging flowers: 5.77%
#    playing poker: 4.78%
# Top predictions:
#
#          writing: 13.51%
# using remote controller (not gaming): 9.88%
# arranging flowers: 7.23%
#    setting table: 6.19%
#           dining: 4.25%
# Top predictions:
#
#          writing: 13.78%
# using remote controller (not gaming): 12.95%
# arranging flowers: 8.36%
#    setting table: 5.57%
#   using computer: 5.23%
# Top predictions:
#
# using remote controller (not gaming): 14.20%
#          writing: 13.76%
# arranging flowers: 5.73%
#    setting table: 5.39%
#   using computer: 4.61%
# Top predictions:
#
#          writing: 14.20%
# using remote controller (not gaming): 9.46%
# arranging flowers: 6.92%
#    setting table: 5.74%
#    playing poker: 5.06%
# Top predictions:
#
#          writing: 15.23%
# using remote controller (not gaming): 12.24%
# arranging flowers: 8.15%
#   using computer: 5.97%
#    setting table: 4.79%
# Top predictions:
#
#          writing: 15.76%
# using remote controller (not gaming): 13.48%
# arranging flowers: 8.98%
#   using computer: 5.28%
#    setting table: 4.24%
# Top predictions:
#
#          writing: 17.60%
# using remote controller (not gaming): 11.37%
# arranging flowers: 7.57%
#    setting table: 6.48%
#   using computer: 4.59%
# Top predictions:
#
#          writing: 14.77%
# using remote controller (not gaming): 13.45%
# arranging flowers: 7.67%
#    setting table: 6.35%
#    playing poker: 4.23%
# Top predictions:
#
# using remote controller (not gaming): 14.58%
#          writing: 14.58%
# arranging flowers: 7.33%
#    setting table: 4.88%
#   using computer: 4.31%
# Top predictions:
#
# using remote controller (not gaming): 14.94%
#          writing: 12.01%
# arranging flowers: 9.64%
#   using computer: 6.04%
#    setting table: 5.00%
# Top predictions:
#
#          writing: 16.33%
# using remote controller (not gaming): 13.12%
# arranging flowers: 7.03%
#    setting table: 5.30%
#   using computer: 5.14%
# Top predictions:
#
#          writing: 14.78%
# using remote controller (not gaming): 12.65%
# arranging flowers: 8.42%
#   using computer: 4.95%
#    setting table: 4.80%
# Top predictions:
#
#          writing: 14.39%
# using remote controller (not gaming): 12.70%
# arranging flowers: 7.46%
#    setting table: 5.81%
#   using computer: 4.39%
# Top predictions:
#
#          writing: 15.17%
# using remote controller (not gaming): 11.10%
# arranging flowers: 8.92%
#    setting table: 5.94%
#   using computer: 5.24%
# Top predictions:
#
# using remote controller (not gaming): 12.35%
#          writing: 11.98%
# arranging flowers: 9.04%
#    setting table: 5.48%
#   using computer: 4.84%
# Top predictions:
#
#          writing: 14.76%
# using remote controller (not gaming): 13.44%
# arranging flowers: 7.65%
#    setting table: 6.55%
#   using computer: 4.64%
# Top predictions:
#
#          writing: 13.33%
# using remote controller (not gaming): 9.16%
#    setting table: 9.16%
# arranging flowers: 8.34%
#           dining: 6.10%
# Top predictions:
#
#          writing: 15.94%
# using remote controller (not gaming): 10.29%
# arranging flowers: 7.77%
#    setting table: 7.30%
#           dining: 4.57%
# Top predictions:
#
#          writing: 16.93%
# using remote controller (not gaming): 11.63%
# arranging flowers: 7.06%
#   using computer: 6.04%
#    setting table: 4.15%
# Top predictions:
#
#          writing: 18.53%
# using remote controller (not gaming): 10.23%
# arranging flowers: 9.03%
#    setting table: 6.02%
#   using computer: 4.83%
# Top predictions:
#
#          writing: 17.98%
# using remote controller (not gaming): 9.93%
# arranging flowers: 8.49%
#    setting table: 7.50%
#   using computer: 4.14%
# Top predictions:
#
#          writing: 17.50%
# using remote controller (not gaming): 13.21%
# arranging flowers: 9.37%
#    setting table: 5.34%
#   using computer: 4.86%
# Top predictions:
#
#          writing: 14.49%
# using remote controller (not gaming): 10.28%
# arranging flowers: 9.66%
#    setting table: 6.43%
#           dining: 4.86%
# Top predictions:
#
#          writing: 15.94%
# using remote controller (not gaming): 13.22%
# arranging flowers: 7.77%
#    setting table: 6.24%
#   using computer: 5.69%
# Top predictions:
#
#          writing: 19.14%
# using remote controller (not gaming): 9.63%
# arranging flowers: 8.76%
#    setting table: 6.02%
#   using computer: 4.41%
# Top predictions:
#
#          writing: 12.84%
# using remote controller (not gaming): 10.64%
# arranging flowers: 8.29%
#    setting table: 5.19%
#    playing poker: 4.72%
# Top predictions:
#
#          writing: 14.40%
# using remote controller (not gaming): 11.21%
# arranging flowers: 10.53%
#    setting table: 6.59%
#   using computer: 4.26%
# Top predictions:
#
#          writing: 16.14%
# using remote controller (not gaming): 11.44%
# arranging flowers: 7.39%
#    setting table: 6.52%
#   using computer: 4.21%
# Top predictions:
#
#          writing: 17.10%
# using remote controller (not gaming): 9.15%
# arranging flowers: 8.87%
#    setting table: 6.29%
#   using computer: 4.06%
# Top predictions:
#
#          writing: 18.93%
# using remote controller (not gaming): 11.13%
# arranging flowers: 8.40%
#   using computer: 5.26%
#    setting table: 5.26%
# Top predictions:
#
#          writing: 18.51%
# using remote controller (not gaming): 12.33%
# arranging flowers: 7.03%
#   using computer: 5.30%
#    setting table: 4.53%
# Top predictions:
#
#          writing: 16.81%
# using remote controller (not gaming): 11.20%
# arranging flowers: 9.88%
#    setting table: 5.81%
#   using computer: 5.13%
# Top predictions:
#
#          writing: 19.12%
# using remote controller (not gaming): 8.75%
#    setting table: 6.60%
# arranging flowers: 6.60%
#           dining: 4.13%
# Top predictions:
#
#          writing: 17.24%
# arranging flowers: 10.78%
# using remote controller (not gaming): 9.52%
#    setting table: 5.96%
#   using computer: 4.36%
# Top predictions:
#
#          writing: 19.98%
# using remote controller (not gaming): 12.51%
# arranging flowers: 8.87%
#   using computer: 6.49%
#    playing poker: 3.47%
# Top predictions:
#
#          writing: 21.35%
# arranging flowers: 9.19%
# using remote controller (not gaming): 7.61%
#    setting table: 5.75%
#   using computer: 4.92%
# Top predictions:
#
#          writing: 19.35%
# using remote controller (not gaming): 11.02%
# arranging flowers: 9.73%
#   using computer: 5.21%
#    setting table: 4.45%
# Top predictions:
#
#          writing: 19.59%
# using remote controller (not gaming): 9.85%
# arranging flowers: 9.25%
#   using computer: 5.44%
#    setting table: 4.37%
# Top predictions:
#
#          writing: 16.89%
# using remote controller (not gaming): 10.91%
# arranging flowers: 8.76%
#    setting table: 5.31%
#   using computer: 4.69%
# Top predictions:
#
#          writing: 17.44%
# using remote controller (not gaming): 10.91%
# arranging flowers: 10.25%
#    setting table: 6.03%
#   using computer: 5.49%
# Top predictions:
#
#          writing: 17.64%
# using remote controller (not gaming): 11.39%
# arranging flowers: 8.59%
#    setting table: 6.49%
#   using computer: 5.21%
# Top predictions:
#
#          writing: 13.92%
# using remote controller (not gaming): 8.98%
# arranging flowers: 6.57%
#    setting table: 5.62%
#   using computer: 4.38%
# Top predictions:
#
#          writing: 15.50%
# using remote controller (not gaming): 10.65%
# arranging flowers: 8.29%
#    setting table: 5.70%
#   using computer: 4.30%
# Top predictions:
#
#          writing: 17.74%
# using remote controller (not gaming): 9.20%
# arranging flowers: 7.63%
#    setting table: 6.52%
#   using computer: 4.21%
# Top predictions:
#
#          writing: 16.44%
# using remote controller (not gaming): 10.62%
# arranging flowers: 8.53%
#    setting table: 7.07%
#   using computer: 4.03%
# Top predictions:
#
#          writing: 14.31%
#    setting table: 8.95%
# arranging flowers: 8.95%
# using remote controller (not gaming): 8.15%
#           dining: 5.78%
# Top predictions:
#
#          writing: 17.92%
# using remote controller (not gaming): 12.31%
# arranging flowers: 7.70%
#    setting table: 6.19%
#   using computer: 5.29%
# Top predictions:
#
#          writing: 18.90%
# using remote controller (not gaming): 12.99%
# arranging flowers: 7.64%
#   using computer: 5.58%
#    setting table: 4.63%
# Top predictions:
#
#          writing: 18.31%
# using remote controller (not gaming): 11.46%
# arranging flowers: 7.17%
#    setting table: 5.41%
#   using computer: 5.08%
# Top predictions:
#
#          writing: 16.76%
# using remote controller (not gaming): 9.55%
# arranging flowers: 8.43%
#    setting table: 5.44%
#   using computer: 4.24%
# Top predictions:
#
#          writing: 17.00%
# using remote controller (not gaming): 10.98%
# arranging flowers: 9.10%
#   using computer: 5.35%
#    setting table: 4.58%
# Top predictions:
#
#          writing: 19.07%
# using remote controller (not gaming): 9.30%
# arranging flowers: 9.30%
#   using computer: 4.39%
#    setting table: 4.39%
# Top predictions:
#
#          writing: 16.72%
# using remote controller (not gaming): 8.67%
# arranging flowers: 7.65%
#    setting table: 5.60%
#   using computer: 5.43%
# Top predictions:
#
#          writing: 18.65%
# using remote controller (not gaming): 9.38%
# arranging flowers: 8.54%
#    setting table: 5.51%
#   using computer: 4.71%
# Top predictions:
#
#          writing: 14.65%
# using remote controller (not gaming): 11.06%
# arranging flowers: 8.35%
#    setting table: 5.06%
#   using computer: 4.47%
# Top predictions:
#
#          writing: 14.29%
# using remote controller (not gaming): 11.14%
# arranging flowers: 9.23%
#   using computer: 5.96%
#    setting table: 5.60%
# Top predictions:
#
#          writing: 18.59%
# using remote controller (not gaming): 9.95%
# arranging flowers: 9.65%
#   using computer: 5.16%
#    setting table: 5.00%
# Top predictions:
#
# using remote controller (not gaming): 14.05%
#          writing: 12.02%
#    setting table: 7.07%
# arranging flowers: 5.01%
#           dining: 4.28%
# Top predictions:
#
#          writing: 16.80%
# using remote controller (not gaming): 9.57%
#   eating carrots: 4.25%
# arranging flowers: 4.12%
#           dining: 3.99%
# Top predictions:
#
#          writing: 15.48%
# using remote controller (not gaming): 10.98%
# arranging flowers: 6.66%
#    setting table: 4.72%
#    playing poker: 4.72%
# Top predictions:
#
# using remote controller (not gaming): 16.16%
#          writing: 16.16%
# arranging flowers: 7.64%
#   using computer: 7.17%
#    playing poker: 4.09%
# Top predictions:
#
#          writing: 13.78%
# using remote controller (not gaming): 11.07%
# arranging flowers: 8.36%
#    setting table: 6.31%
#    playing poker: 4.61%
# Top predictions:
#
#          writing: 16.08%
# using remote controller (not gaming): 9.45%
# arranging flowers: 6.49%
#    setting table: 5.73%
#   using computer: 5.06%
# Top predictions:
#
#          writing: 14.69%
# using remote controller (not gaming): 9.48%
# arranging flowers: 8.37%
#    setting table: 6.52%
#    playing poker: 4.92%
# Top predictions:
#
#          writing: 16.86%
# using remote controller (not gaming): 11.59%
# arranging flowers: 6.01%
#   using computer: 4.54%
#    setting table: 4.54%
# Top predictions:
#
#          writing: 16.64%
# using remote controller (not gaming): 9.48%
#    setting table: 6.12%
# arranging flowers: 5.23%
#           dining: 4.77%
# Top predictions:
#
#          writing: 17.77%
# using remote controller (not gaming): 13.84%
# arranging flowers: 5.95%
#    setting table: 5.77%
#   using computer: 5.09%
